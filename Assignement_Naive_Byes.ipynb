# %% [markdown]
# # Assignement_Naive_Byes

# %% [markdown]
# ## Problem Statement: Prepare a classification model using Naive Bayes for salary data
#
# __Data Description:__<br>
#
#
# - age -- age of a person
# - workclass	-- A work class is a grouping of work
# - education	-- Education of an individuals
# - maritalstatus -- Marital status of an individulas
# - occupation	 -- occupation of an individuals
# - relationship --
# - race --  Race of an Individual
# - sex --  Gender of an Individual
# - capitalgain --  profit received from the sale of an investment
# - capitalloss	-- A decrease in the value of a capital asset
# - hoursperweek -- number of hours work per week
# - native -- Native of an individual
# - Salary -- salary of an individua

# %% [markdown]
# # Naive Bayes on Categorical Data

# %%
from sklearn.naive_bayes import CategoricalNB
clf = CategoricalNB()

# %%
import pandas as pd
SalaryData_Train=pd.read_csv('SalaryData_Train.csv')
SalaryData_Train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %% [markdown]
# __We have two categories of Salary 1)  <= 50 K and 2) >50K__

# %%
SalaryData_Train_label=SalaryData_Train.copy()
SalaryData_Train_label.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
SalaryData_Train_label.iloc[:, -1] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,-1])
SalaryData_Train_label.iloc[:, 1] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,1])
SalaryData_Train_label.iloc[:, 2] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,2])
SalaryData_Train_label.iloc[:, 4] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,4])
SalaryData_Train_label.iloc[:, 5] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,5])
SalaryData_Train_label.iloc[:, 6] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,6])
SalaryData_Train_label.iloc[:, 7] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,7])
SalaryData_Train_label.iloc[:, 8] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,8])
SalaryData_Train_label.iloc[:, 12] = labelencoder.fit_transform(SalaryData_Train_label.iloc[:,9])

# %%
SalaryData_Train_label
#Outlook:  Sunny=2, Overcast=0, Rainy=1
#Temperature: Hot=1, Mild=2, Cool=0
#Humidity: High=0, Normal=1
#Windy: Yes=1, No=0
#Play= Yes=1, No=0
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
X=SalaryData_Train_label.iloc[:,:-1]
Y=SalaryData_Train_label.iloc[:,-1]

# %%
clf.fit(X, Y)
# Out:
# CategoricalNB()

# %%
#Calculate prediction for Outlook=Sunny,Temperature=Mild,Humidity=Normal,& Windy=No

# %%
SalaryData_Test=pd.read_csv('SalaryData_Test.csv')

# %%
SalaryData_Test_label=SalaryData_Test.copy()
SalaryData_Test_label.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
SalaryData_Test_label.iloc[:, -1] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,-1])
SalaryData_Test_label.iloc[:, 1] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,1])
SalaryData_Test_label.iloc[:, 2] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,2])
SalaryData_Test_label.iloc[:, 4] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,4])
SalaryData_Test_label.iloc[:, 5] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,5])
SalaryData_Test_label.iloc[:, 6] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,6])
SalaryData_Test_label.iloc[:, 7] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,7])
SalaryData_Test_label.iloc[:, 8] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,8])
SalaryData_Test_label.iloc[:, 12] = labelencoder.fit_transform(SalaryData_Test_label.iloc[:,9])

# %%
import numpy as np
# X_test=np.array([[2,2,1,0]])
X_test=SalaryData_Test_label.iloc[:,:-1]
#X_test.shape
#X_test.reshape(1, -1)

# %%
print(clf.predict(X_test))
# Out:
# [0 0 0 ... 1 0 1]

# %% [markdown]
# 0 id for slkaray <== 50 K
# 1 is for Salary >50K
